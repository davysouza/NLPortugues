# %% [markdown]
# <img src="https://github.com/alan-barzilay/NLPortugues/blob/master/imagens/logo_nlportugues.png?raw=true"  style="height:65%" align="right">
#
#
# # Lista 5 - Vanishing & Exploding Gradient
# **Nome:** Davy Alves de Souza
#
# **Numero Usp:** 11561247
#
#
#
#
#
#
#
#
#
# ______________

# %% [markdown]
# Nessa lista exploraremos alguns problemas que podemos encontrar ao treinarmos uma rede recorrente. Esses problemas não são únicos das redes recorrentes, qualquer rede profunda pode sofrer de vanishing e exploding gradient mas as redes recorrentes são especialmente instaveis devido a utilização da mesma matriz de pesos repetidas vezes.
#
# Começaremos explorando o exploding gradient e alguns de seus sintomas, em seguida utilizaremos gradient cliping para combate-lo.
# Por fim estudaremos uma rede que sofre de vanishing gradient e utilizaremos o [TensorBoard](??) para visualizar os gradientes e pesos da rede para entender melhor sua dinâmica. Exploraremos tambem algumas maneiras de combater o vanishing gradient e como elas alteram a dinâmica da rede através do TensorBoard.
#
#
#
# Para essa aula é necessario instalar o TensorBoard

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
# %load_ext tensorboard

from sklearn.datasets import make_circles
from numpy import where
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.initializers import RandomUniform



import tensorboard
print('Tensorflow: ', tf.__version__)
print('Tensorboard: ', tensorboard.version.VERSION)

from utils import ExtendedTensorBoard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Tensorflow:  2.2.0-rc3
# Tensorboard:  2.3.0

# %% [markdown]
# # Exploding
#
# Para essa parte da lista nós preparamos uma rede, note como a *loss* cresce exponencialmente até virar infinita e logo em seguida NaN. Esse é um sintoma classico de exploding gradient. O gradiente está tão elevado que a cada etapa de backpropagation o passo de atualização dos parametros leva a um aumento na *loss* e isso segue crescendo até que exploda.

# %%
def f1(x):
    return 5+ 10*x

xs = [x for x in range(100)]
ys = [f1(x) for x in range(100)]

# %%
opt = keras.optimizers.SGD()
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer=opt, loss="mean_squared_error")
model.fit(xs,ys,epochs=400)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2235307005050880.0000
# Epoch 2/400
# 4/4 [==============================] - 0s 2ms/step - loss: 178713501630241894167243390976.0000
# Epoch 3/400
# 4/4 [==============================] - 0s 2ms/step - loss: inf
# Epoch 4/400
# 4/4 [==============================] - 0s 2ms/step - loss: inf
# Epoch 5/400
# 4/4 [==============================] - 0s 1ms/step - loss: inf
# Epoch 6/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 7/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 8/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 9/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 10/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 11/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 12/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 13/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 14/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 15/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 16/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 17/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 18/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 19/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 20/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 21/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 22/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 23/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 24/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 25/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 26/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 27/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 28/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 29/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 30/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 31/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 32/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 33/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 34/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 35/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 36/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 37/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 38/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 39/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 40/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 41/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 42/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 43/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 44/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 45/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 46/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 47/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 48/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 49/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 50/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 51/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 52/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 53/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 54/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 55/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 56/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 57/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 58/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 59/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 60/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 61/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 62/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 63/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 64/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 65/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 66/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 67/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 68/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 69/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 70/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 71/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 72/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 73/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 74/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 75/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 76/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 77/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 78/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 79/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 80/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 81/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 82/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 83/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 84/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 85/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 86/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 87/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 88/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 89/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 90/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 91/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 92/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 93/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 94/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 95/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 96/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 97/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 98/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 99/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 100/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 101/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 102/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 103/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 104/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 105/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 106/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 107/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 108/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 109/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 110/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 111/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 112/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 113/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 114/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 115/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 116/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 117/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 118/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 119/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 120/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 121/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 122/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 123/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 124/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 125/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 126/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 127/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 128/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 129/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 130/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 131/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 132/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 133/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 134/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 135/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 136/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 137/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 138/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 139/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 140/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 141/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 142/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 143/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 144/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 145/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 146/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 147/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 148/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 149/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 150/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 151/400
# 4/4 [==============================] - ETA: 0s - loss: n - 0s 1ms/step - loss: nan
# Epoch 152/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 153/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 154/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 155/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 156/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 157/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 158/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 159/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 160/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 161/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 162/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 163/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 164/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 165/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 166/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 167/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 168/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 169/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 170/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 171/400
# 4/4 [==============================] - 0s 1000us/step - loss: nan
# Epoch 172/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 173/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 174/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 175/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 176/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 177/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 178/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 179/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 180/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 181/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 182/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 183/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 184/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 185/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 186/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 187/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 188/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 189/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 190/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 191/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 192/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 193/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 194/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 195/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 196/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 197/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 198/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 199/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 200/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 201/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 202/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 203/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 204/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 205/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 206/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 207/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 208/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 209/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 210/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 211/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 212/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 213/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 214/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 215/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 216/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 217/400
# 4/4 [==============================] - 0s 1000us/step - loss: nan
# Epoch 218/400
# 4/4 [==============================] - 0s 1000us/step - loss: nan
# Epoch 219/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 220/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 221/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 222/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 223/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 224/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 225/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 226/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 227/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 228/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 229/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 230/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 231/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 232/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 233/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 234/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 235/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 236/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 237/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 238/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 239/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 240/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 241/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 242/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 243/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 244/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 245/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 246/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 247/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 248/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 249/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 250/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 251/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 252/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 253/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 254/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 255/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 256/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 257/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 258/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 259/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 260/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 261/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 262/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 263/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 264/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 265/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 266/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 267/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 268/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 269/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 270/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 271/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 272/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 273/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 274/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 275/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 276/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 277/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 278/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 279/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 280/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 281/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 282/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 283/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 284/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 285/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 286/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 287/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 288/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 289/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 290/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 291/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 292/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 293/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 294/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 295/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 296/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 297/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 298/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 299/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 300/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 301/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 302/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 303/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 304/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 305/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 306/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 307/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 308/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 309/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 310/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 311/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 312/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 313/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 314/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 315/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 316/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 317/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 318/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 319/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 320/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 321/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 322/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 323/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 324/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 325/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 326/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 327/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 328/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 329/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 330/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 331/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 332/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 333/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 334/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 335/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 336/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 337/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 338/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 339/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 340/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 341/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 342/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 343/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 344/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 345/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 346/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 347/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 348/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 349/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 350/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 351/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 352/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 353/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 354/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 355/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 356/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 357/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 358/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 359/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 360/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 361/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 362/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 363/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 364/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 365/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 366/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 367/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 368/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 369/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 370/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 371/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 372/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 373/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 374/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 375/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 376/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 377/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 378/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 379/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 380/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 381/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 382/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 383/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 384/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 385/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 386/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 387/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 388/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 389/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 390/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 391/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 392/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 393/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 394/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 395/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 396/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 397/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 398/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 399/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 400/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan

# %% [markdown]
# ## Gradient Cliping
# ## <font color='blue'>Questão 1 </font>
#
#
# Utilizando a mesma arquitetura, realize gradient clipping no otimizador para contornar o problema de exploding gradient, compile e treine seu novo modelo.
# Você pode usar tanto o parametro `clipvalue` quanto `clipnorm` desde que sua rede consiga minimizar a loss.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# Seu código aqui

# Gradient clipping nao funciona com o tensorflow 2.1.x :p

opt = keras.optimizers.SGD(clipvalue=1.0)
model.compile(optimizer=opt, loss="mean_squared_error")

model.fit(xs,ys,epochs=400)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 1ms/step - loss: 327475.6250
# Epoch 2/400
# 4/4 [==============================] - 0s 1ms/step - loss: 357044.8750
# Epoch 3/400
# 4/4 [==============================] - 0s 1ms/step - loss: 333798.3438
# Epoch 4/400
# 4/4 [==============================] - 0s 2ms/step - loss: 312453.2500
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: 266580.4375
# Epoch 6/400
# 4/4 [==============================] - 0s 1ms/step - loss: 266268.0312
# Epoch 7/400
# 4/4 [==============================] - 0s 1ms/step - loss: 300485.8438
# Epoch 8/400
# 4/4 [==============================] - 0s 2ms/step - loss: 248724.8906
# Epoch 9/400
# 4/4 [==============================] - 0s 2ms/step - loss: 282662.0625
# Epoch 10/400
# 4/4 [==============================] - 0s 2ms/step - loss: 254967.2500
# Epoch 11/400
# 4/4 [==============================] - 0s 2ms/step - loss: 240049.9844
# Epoch 12/400
# 4/4 [==============================] - 0s 1ms/step - loss: 312014.3438
# Epoch 13/400
# 4/4 [==============================] - 0s 2ms/step - loss: 280126.7500
# Epoch 14/400
# 4/4 [==============================] - 0s 1ms/step - loss: 269113.5625
# Epoch 15/400
# 4/4 [==============================] - 0s 2ms/step - loss: 254089.1719
# Epoch 16/400
# 4/4 [==============================] - 0s 2ms/step - loss: 303190.1562
# Epoch 17/400
# 4/4 [==============================] - 0s 2ms/step - loss: 296510.5000
# Epoch 18/400
# 4/4 [==============================] - 0s 1ms/step - loss: 247721.3750
# Epoch 19/400
# 4/4 [==============================] - 0s 1ms/step - loss: 230441.9688
# Epoch 20/400
# 4/4 [==============================] - 0s 1ms/step - loss: 290179.4062
# Epoch 21/400
# 4/4 [==============================] - 0s 2ms/step - loss: 272502.6875
# Epoch 22/400
# 4/4 [==============================] - 0s 2ms/step - loss: 255605.1250
# Epoch 23/400
# 4/4 [==============================] - 0s 1ms/step - loss: 234681.6719
# Epoch 24/400
# 4/4 [==============================] - 0s 2ms/step - loss: 238541.7188
# Epoch 25/400
# 4/4 [==============================] - 0s 1ms/step - loss: 285874.1562
# Epoch 26/400
# 4/4 [==============================] - 0s 2ms/step - loss: 263906.8438
# Epoch 27/400
# 4/4 [==============================] - 0s 2ms/step - loss: 258281.8281
# Epoch 28/400
# 4/4 [==============================] - 0s 2ms/step - loss: 252387.9688
# Epoch 29/400
# 4/4 [==============================] - 0s 2ms/step - loss: 261161.2656
# Epoch 30/400
# 4/4 [==============================] - 0s 1ms/step - loss: 219594.9062
# Epoch 31/400
# 4/4 [==============================] - 0s 2ms/step - loss: 204982.8906
# Epoch 32/400
# 4/4 [==============================] - 0s 1ms/step - loss: 243957.1250
# Epoch 33/400
# 4/4 [==============================] - 0s 2ms/step - loss: 223614.5781
# Epoch 34/400
# 4/4 [==============================] - 0s 2ms/step - loss: 241826.3438
# Epoch 35/400
# 4/4 [==============================] - 0s 1ms/step - loss: 253922.3281
# Epoch 36/400
# 4/4 [==============================] - 0s 2ms/step - loss: 221581.5469
# Epoch 37/400
# 4/4 [==============================] - 0s 1ms/step - loss: 203152.5469
# Epoch 38/400
# 4/4 [==============================] - 0s 1ms/step - loss: 268363.7500
# Epoch 39/400
# 4/4 [==============================] - 0s 2ms/step - loss: 220786.6875
# Epoch 40/400
# 4/4 [==============================] - 0s 2ms/step - loss: 202269.4219
# Epoch 41/400
# 4/4 [==============================] - 0s 1ms/step - loss: 221492.4375
# Epoch 42/400
# 4/4 [==============================] - 0s 2ms/step - loss: 224536.6562
# Epoch 43/400
# 4/4 [==============================] - 0s 2ms/step - loss: 205497.4219
# Epoch 44/400
# 4/4 [==============================] - 0s 2ms/step - loss: 204116.7188
# Epoch 45/400
# 4/4 [==============================] - 0s 2ms/step - loss: 195886.0000
# Epoch 46/400
# 4/4 [==============================] - 0s 2ms/step - loss: 171228.6094
# Epoch 47/400
# 4/4 [==============================] - 0s 2ms/step - loss: 199682.9375
# Epoch 48/400
# 4/4 [==============================] - 0s 2ms/step - loss: 207018.3438
# Epoch 49/400
# 4/4 [==============================] - 0s 2ms/step - loss: 180051.3438
# Epoch 50/400
# 4/4 [==============================] - 0s 2ms/step - loss: 192083.5938
# Epoch 51/400
# 4/4 [==============================] - 0s 2ms/step - loss: 229681.5000
# Epoch 52/400
# 4/4 [==============================] - 0s 2ms/step - loss: 199654.1250
# Epoch 53/400
# 4/4 [==============================] - 0s 1ms/step - loss: 204258.7031
# Epoch 54/400
# 4/4 [==============================] - 0s 2ms/step - loss: 196859.2656
# Epoch 55/400
# 4/4 [==============================] - 0s 2ms/step - loss: 166058.3281
# Epoch 56/400
# 4/4 [==============================] - 0s 1ms/step - loss: 170085.0625
# Epoch 57/400
# 4/4 [==============================] - 0s 2ms/step - loss: 163185.5156
# Epoch 58/400
# 4/4 [==============================] - 0s 2ms/step - loss: 213999.8594
# Epoch 59/400
# 4/4 [==============================] - 0s 2ms/step - loss: 147534.9844
# Epoch 60/400
# 4/4 [==============================] - 0s 2ms/step - loss: 187201.1875
# Epoch 61/400
# 4/4 [==============================] - 0s 1ms/step - loss: 183395.3594
# Epoch 62/400
# 4/4 [==============================] - 0s 2ms/step - loss: 187655.6875
# Epoch 63/400
# 4/4 [==============================] - 0s 2ms/step - loss: 138894.9531
# Epoch 64/400
# 4/4 [==============================] - 0s 2ms/step - loss: 168704.0312
# Epoch 65/400
# 4/4 [==============================] - 0s 2ms/step - loss: 155144.0938
# Epoch 66/400
# 4/4 [==============================] - 0s 2ms/step - loss: 144728.1094
# Epoch 67/400
# 4/4 [==============================] - 0s 1ms/step - loss: 156832.2812
# Epoch 68/400
# 4/4 [==============================] - 0s 2ms/step - loss: 135138.2344
# Epoch 69/400
# 4/4 [==============================] - 0s 2ms/step - loss: 137711.8906
# Epoch 70/400
# 4/4 [==============================] - 0s 2ms/step - loss: 165867.4531
# Epoch 71/400
# 4/4 [==============================] - 0s 1ms/step - loss: 151847.9062
# Epoch 72/400
# 4/4 [==============================] - 0s 2ms/step - loss: 146074.8438
# Epoch 73/400
# 4/4 [==============================] - 0s 1ms/step - loss: 135760.6094
# Epoch 74/400
# 4/4 [==============================] - 0s 1ms/step - loss: 143967.5000
# Epoch 75/400
# 4/4 [==============================] - 0s 1ms/step - loss: 146776.1875
# Epoch 76/400
# 4/4 [==============================] - 0s 2ms/step - loss: 143274.8125
# Epoch 77/400
# 4/4 [==============================] - 0s 1ms/step - loss: 160949.0781
# Epoch 78/400
# 4/4 [==============================] - 0s 1ms/step - loss: 142634.7812
# Epoch 79/400
# 4/4 [==============================] - 0s 1ms/step - loss: 141145.6562
# Epoch 80/400
# 4/4 [==============================] - 0s 1ms/step - loss: 136603.1562
# Epoch 81/400
# 4/4 [==============================] - 0s 1ms/step - loss: 141345.8750
# Epoch 82/400
# 4/4 [==============================] - 0s 2ms/step - loss: 120457.7891
# Epoch 83/400
# 4/4 [==============================] - 0s 2ms/step - loss: 136963.5156
# Epoch 84/400
# 4/4 [==============================] - 0s 1ms/step - loss: 116534.3672
# Epoch 85/400
# 4/4 [==============================] - 0s 1ms/step - loss: 135921.8906
# Epoch 86/400
# 4/4 [==============================] - 0s 2ms/step - loss: 131087.9844
# Epoch 87/400
# 4/4 [==============================] - 0s 2ms/step - loss: 104137.7344
# Epoch 88/400
# 4/4 [==============================] - 0s 1ms/step - loss: 117505.0781
# Epoch 89/400
# 4/4 [==============================] - 0s 2ms/step - loss: 103959.9219
# Epoch 90/400
# 4/4 [==============================] - 0s 2ms/step - loss: 125181.7656
# Epoch 91/400
# 4/4 [==============================] - 0s 2ms/step - loss: 133611.6562
# Epoch 92/400
# 4/4 [==============================] - 0s 2ms/step - loss: 131615.4219
# Epoch 93/400
# 4/4 [==============================] - 0s 1ms/step - loss: 94579.0781
# Epoch 94/400
# 4/4 [==============================] - 0s 1ms/step - loss: 129177.6875
# Epoch 95/400
# 4/4 [==============================] - ETA: 0s - loss: 119402.35 - 0s 1ms/step - loss: 108019.0078
# Epoch 96/400
# 4/4 [==============================] - 0s 1ms/step - loss: 130276.6562
# Epoch 97/400
# 4/4 [==============================] - 0s 2ms/step - loss: 115515.7969
# Epoch 98/400
# 4/4 [==============================] - 0s 2ms/step - loss: 113769.7266
# Epoch 99/400
# 4/4 [==============================] - 0s 2ms/step - loss: 104148.6172
# Epoch 100/400
# 4/4 [==============================] - 0s 1ms/step - loss: 102238.4062
# Epoch 101/400
# 4/4 [==============================] - 0s 1ms/step - loss: 101582.7422
# Epoch 102/400
# 4/4 [==============================] - 0s 2ms/step - loss: 89672.8047
# Epoch 103/400
# 4/4 [==============================] - 0s 1ms/step - loss: 103894.6875
# Epoch 104/400
# 4/4 [==============================] - 0s 2ms/step - loss: 122697.6172
# Epoch 105/400
# 4/4 [==============================] - 0s 2ms/step - loss: 104662.5938
# Epoch 106/400
# 4/4 [==============================] - 0s 1ms/step - loss: 87621.3125
# Epoch 107/400
# 4/4 [==============================] - 0s 1ms/step - loss: 75296.3828
# Epoch 108/400
# 4/4 [==============================] - 0s 1ms/step - loss: 92226.9297
# Epoch 109/400
# 4/4 [==============================] - 0s 2ms/step - loss: 93980.7344
# Epoch 110/400
# 4/4 [==============================] - 0s 1ms/step - loss: 96677.9297
# Epoch 111/400
# 4/4 [==============================] - 0s 1ms/step - loss: 105601.7656
# Epoch 112/400
# 4/4 [==============================] - 0s 2ms/step - loss: 84610.7891
# Epoch 113/400
# 4/4 [==============================] - 0s 2ms/step - loss: 73513.4688
# Epoch 114/400
# 4/4 [==============================] - 0s 2ms/step - loss: 98215.8750
# Epoch 115/400
# 4/4 [==============================] - 0s 1ms/step - loss: 78227.0938
# Epoch 116/400
# 4/4 [==============================] - 0s 2ms/step - loss: 76713.0000
# Epoch 117/400
# 4/4 [==============================] - 0s 2ms/step - loss: 82502.5547
# Epoch 118/400
# 4/4 [==============================] - 0s 2ms/step - loss: 85492.0312
# Epoch 119/400
# 4/4 [==============================] - 0s 2ms/step - loss: 70389.9688
# Epoch 120/400
# 4/4 [==============================] - 0s 2ms/step - loss: 88786.9844
# Epoch 121/400
# 4/4 [==============================] - 0s 2ms/step - loss: 73359.5703
# Epoch 122/400
# 4/4 [==============================] - 0s 2ms/step - loss: 81059.4922
# Epoch 123/400
# 4/4 [==============================] - 0s 2ms/step - loss: 80742.9609
# Epoch 124/400
# 4/4 [==============================] - 0s 1ms/step - loss: 77825.5703
# Epoch 125/400
# 4/4 [==============================] - 0s 2ms/step - loss: 61814.8203
# Epoch 126/400
# 4/4 [==============================] - 0s 1ms/step - loss: 75534.1875
# Epoch 127/400
# 4/4 [==============================] - 0s 1ms/step - loss: 66434.4375
# Epoch 128/400
# 4/4 [==============================] - 0s 2ms/step - loss: 65165.9375
# Epoch 129/400
# 4/4 [==============================] - 0s 2ms/step - loss: 61794.7500
# Epoch 130/400
# 4/4 [==============================] - 0s 2ms/step - loss: 68354.3750
# Epoch 131/400
# 4/4 [==============================] - 0s 1ms/step - loss: 58979.4219
# Epoch 132/400
# 4/4 [==============================] - 0s 1ms/step - loss: 63688.4297
# Epoch 133/400
# 4/4 [==============================] - 0s 1ms/step - loss: 69368.8438
# Epoch 134/400
# 4/4 [==============================] - 0s 1ms/step - loss: 51861.8047
# Epoch 135/400
# 4/4 [==============================] - 0s 2ms/step - loss: 59635.1797
# Epoch 136/400
# 4/4 [==============================] - 0s 1ms/step - loss: 56004.9961
# Epoch 137/400
# 4/4 [==============================] - 0s 1ms/step - loss: 53913.4883
# Epoch 138/400
# 4/4 [==============================] - 0s 2ms/step - loss: 48942.7539
# Epoch 139/400
# 4/4 [==============================] - 0s 1ms/step - loss: 61147.9062
# Epoch 140/400
# 4/4 [==============================] - 0s 1ms/step - loss: 43496.9688
# Epoch 141/400
# 4/4 [==============================] - 0s 2ms/step - loss: 53368.3906
# Epoch 142/400
# 4/4 [==============================] - 0s 1ms/step - loss: 53431.9180
# Epoch 143/400
# 4/4 [==============================] - 0s 1ms/step - loss: 51766.1250
# Epoch 144/400
# 4/4 [==============================] - 0s 1ms/step - loss: 40661.7383
# Epoch 145/400
# 4/4 [==============================] - 0s 1ms/step - loss: 50270.5312
# Epoch 146/400
# 4/4 [==============================] - 0s 2ms/step - loss: 56164.9258
# Epoch 147/400
# 4/4 [==============================] - 0s 2ms/step - loss: 46329.3242
# Epoch 148/400
# 4/4 [==============================] - 0s 1ms/step - loss: 42046.5820
# Epoch 149/400
# 4/4 [==============================] - 0s 2ms/step - loss: 43508.9922
# Epoch 150/400
# 4/4 [==============================] - 0s 2ms/step - loss: 38176.3906
# Epoch 151/400
# 4/4 [==============================] - 0s 2ms/step - loss: 37227.6523
# Epoch 152/400
# 4/4 [==============================] - 0s 2ms/step - loss: 38964.7031
# Epoch 153/400
# 4/4 [==============================] - 0s 1ms/step - loss: 45670.9141
# Epoch 154/400
# 4/4 [==============================] - 0s 1ms/step - loss: 43104.8125
# Epoch 155/400
# 4/4 [==============================] - 0s 1ms/step - loss: 38316.1484
# Epoch 156/400
# 4/4 [==============================] - 0s 2ms/step - loss: 38813.7109
# Epoch 157/400
# 4/4 [==============================] - 0s 2ms/step - loss: 39530.4102
# Epoch 158/400
# 4/4 [==============================] - 0s 1ms/step - loss: 36163.5781
# Epoch 159/400
# 4/4 [==============================] - 0s 2ms/step - loss: 36467.6797
# Epoch 160/400
# 4/4 [==============================] - 0s 2ms/step - loss: 35075.1094
# Epoch 161/400
# 4/4 [==============================] - ETA: 0s - loss: 33555.179 - 0s 2ms/step - loss: 38167.4375
# Epoch 162/400
# 4/4 [==============================] - 0s 2ms/step - loss: 31132.6758
# Epoch 163/400
# 4/4 [==============================] - 0s 2ms/step - loss: 38382.0703
# Epoch 164/400
# 4/4 [==============================] - 0s 1ms/step - loss: 32327.8047
# Epoch 165/400
# 4/4 [==============================] - 0s 1ms/step - loss: 26948.8730
# Epoch 166/400
# 4/4 [==============================] - 0s 2ms/step - loss: 35834.9883
# Epoch 167/400
# 4/4 [==============================] - 0s 1ms/step - loss: 29448.5508
# Epoch 168/400
# 4/4 [==============================] - 0s 1ms/step - loss: 26004.5410
# Epoch 169/400
# 4/4 [==============================] - 0s 2ms/step - loss: 27339.0664
# Epoch 170/400
# 4/4 [==============================] - 0s 2ms/step - loss: 25092.8848
# Epoch 171/400
# 4/4 [==============================] - 0s 2ms/step - loss: 25925.8750
# Epoch 172/400
# 4/4 [==============================] - 0s 2ms/step - loss: 24723.0508
# Epoch 173/400
# 4/4 [==============================] - 0s 2ms/step - loss: 22650.4922
# Epoch 174/400
# 4/4 [==============================] - 0s 2ms/step - loss: 21213.5586
# Epoch 175/400
# 4/4 [==============================] - 0s 1ms/step - loss: 17456.3730
# Epoch 176/400
# 4/4 [==============================] - 0s 1ms/step - loss: 20360.4160
# Epoch 177/400
# 4/4 [==============================] - 0s 1ms/step - loss: 23227.2637
# Epoch 178/400
# 4/4 [==============================] - 0s 1ms/step - loss: 20348.2734
# Epoch 179/400
# 4/4 [==============================] - 0s 1ms/step - loss: 20536.7051
# Epoch 180/400
# 4/4 [==============================] - 0s 2ms/step - loss: 16938.5195
# Epoch 181/400
# 4/4 [==============================] - 0s 2ms/step - loss: 16345.6182
# Epoch 182/400
# 4/4 [==============================] - 0s 2ms/step - loss: 17107.6484
# Epoch 183/400
# 4/4 [==============================] - 0s 1ms/step - loss: 17394.3477
# Epoch 184/400
# 4/4 [==============================] - 0s 2ms/step - loss: 16703.1895
# Epoch 185/400
# 4/4 [==============================] - 0s 2ms/step - loss: 14042.0898
# Epoch 186/400
# 4/4 [==============================] - 0s 2ms/step - loss: 13609.6348
# Epoch 187/400
# 4/4 [==============================] - 0s 2ms/step - loss: 13252.0088
# Epoch 188/400
# 4/4 [==============================] - 0s 2ms/step - loss: 14713.3945
# Epoch 189/400
# 4/4 [==============================] - 0s 2ms/step - loss: 13780.0391
# Epoch 190/400
# 4/4 [==============================] - 0s 2ms/step - loss: 13733.3564
# Epoch 191/400
# 4/4 [==============================] - 0s 2ms/step - loss: 11136.7988
# Epoch 192/400
# 4/4 [==============================] - 0s 1ms/step - loss: 12548.3672
# Epoch 193/400
# 4/4 [==============================] - 0s 2ms/step - loss: 11293.3057
# Epoch 194/400
# 4/4 [==============================] - 0s 2ms/step - loss: 10142.5371
# Epoch 195/400
# 4/4 [==============================] - 0s 1ms/step - loss: 12451.7061
# Epoch 196/400
# 4/4 [==============================] - 0s 2ms/step - loss: 10139.2324
# Epoch 197/400
# 4/4 [==============================] - 0s 2ms/step - loss: 9830.1953
# Epoch 198/400
# 4/4 [==============================] - 0s 2ms/step - loss: 9193.1875
# Epoch 199/400
# 4/4 [==============================] - 0s 2ms/step - loss: 7605.7832
# Epoch 200/400
# 4/4 [==============================] - 0s 2ms/step - loss: 7257.6992
# Epoch 201/400
# 4/4 [==============================] - 0s 2ms/step - loss: 7425.9761
# Epoch 202/400
# 4/4 [==============================] - 0s 1ms/step - loss: 6348.8481
# Epoch 203/400
# 4/4 [==============================] - 0s 2ms/step - loss: 6512.3535
# Epoch 204/400
# 4/4 [==============================] - 0s 2ms/step - loss: 6358.4126
# Epoch 205/400
# 4/4 [==============================] - 0s 1ms/step - loss: 6665.1392
# Epoch 206/400
# 4/4 [==============================] - 0s 1ms/step - loss: 5993.6846
# Epoch 207/400
# 4/4 [==============================] - 0s 1ms/step - loss: 6152.1914
# Epoch 208/400
# 4/4 [==============================] - 0s 1ms/step - loss: 5129.0400
# Epoch 209/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4625.5547
# Epoch 210/400
# 4/4 [==============================] - 0s 2ms/step - loss: 5205.2051
# Epoch 211/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4534.8599
# Epoch 212/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3357.4976
# Epoch 213/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3735.7627
# Epoch 214/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3423.0256
# Epoch 215/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2986.6274
# Epoch 216/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3316.1995
# Epoch 217/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2703.6445
# Epoch 218/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2185.7078
# Epoch 219/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2185.6855
# Epoch 220/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1726.8447
# Epoch 221/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1793.8047
# Epoch 222/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1667.6738
# Epoch 223/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1333.8185
# Epoch 224/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1367.0833
# Epoch 225/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1095.2013
# Epoch 226/400
# 4/4 [==============================] - 0s 2ms/step - loss: 945.4768
# Epoch 227/400
# 4/4 [==============================] - 0s 2ms/step - loss: 854.2194
# Epoch 228/400
# 4/4 [==============================] - 0s 2ms/step - loss: 551.9901
# Epoch 229/400
# 4/4 [==============================] - 0s 2ms/step - loss: 572.7637
# Epoch 230/400
# 4/4 [==============================] - 0s 2ms/step - loss: 435.4378
# Epoch 231/400
# 4/4 [==============================] - 0s 2ms/step - loss: 373.8634
# Epoch 232/400
# 4/4 [==============================] - 0s 2ms/step - loss: 252.1969
# Epoch 233/400
# 4/4 [==============================] - 0s 2ms/step - loss: 212.5818
# Epoch 234/400
# 4/4 [==============================] - 0s 1ms/step - loss: 130.4187
# Epoch 235/400
# 4/4 [==============================] - 0s 2ms/step - loss: 86.0466
# Epoch 236/400
# 4/4 [==============================] - 0s 1ms/step - loss: 54.1444
# Epoch 237/400
# 4/4 [==============================] - 0s 2ms/step - loss: 26.8707
# Epoch 238/400
# 4/4 [==============================] - 0s 2ms/step - loss: 19.1003
# Epoch 239/400
# 4/4 [==============================] - 0s 2ms/step - loss: 13.1545
# Epoch 240/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4.9008
# Epoch 241/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4.9280
# Epoch 242/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4.3563
# Epoch 243/400
# 4/4 [==============================] - 0s 2ms/step - loss: 5.0207
# Epoch 244/400
# 4/4 [==============================] - 0s 2ms/step - loss: 5.5952
# Epoch 245/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4.5881
# Epoch 246/400
# 4/4 [==============================] - 0s 2ms/step - loss: 5.5623
# Epoch 247/400
# 4/4 [==============================] - 0s 2ms/step - loss: 5.3553
# Epoch 248/400
# 4/4 [==============================] - 0s 2ms/step - loss: 5.0619
# Epoch 249/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4.5454
# Epoch 250/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4.9613
# Epoch 251/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4.5659
# Epoch 252/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4.5200
# Epoch 253/400
# 4/4 [==============================] - 0s 1ms/step - loss: 5.3819
# Epoch 254/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4.5099
# Epoch 255/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4.5247
# Epoch 256/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.7013
# Epoch 257/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.6666
# Epoch 258/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4.3864
# Epoch 259/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.4939
# Epoch 260/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.6737
# Epoch 261/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9326
# Epoch 262/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4.0395
# Epoch 263/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.3611
# Epoch 264/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.8887
# Epoch 265/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.2898
# Epoch 266/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.2956
# Epoch 267/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.4382
# Epoch 268/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.4022
# Epoch 269/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.8379
# Epoch 270/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.4696
# Epoch 271/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.9056
# Epoch 272/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.9990
# Epoch 273/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.8988
# Epoch 274/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.1646
# Epoch 275/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.7360
# Epoch 276/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.8475
# Epoch 277/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.2094
# Epoch 278/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.8833
# Epoch 279/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.5540
# Epoch 280/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.8196
# Epoch 281/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0405
# Epoch 282/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.0246
# Epoch 283/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.6060
# Epoch 284/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.5854
# Epoch 285/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.5854
# Epoch 286/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3943
# Epoch 287/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6764
# Epoch 288/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.1600
# Epoch 289/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3845
# Epoch 290/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.2045
# Epoch 291/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7599
# Epoch 292/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6593
# Epoch 293/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0092
# Epoch 294/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.9211
# Epoch 295/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.7707
# Epoch 296/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6527
# Epoch 297/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9176
# Epoch 298/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5443
# Epoch 299/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4644
# Epoch 300/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.6161
# Epoch 301/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5574
# Epoch 302/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3417
# Epoch 303/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7113
# Epoch 304/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4409
# Epoch 305/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5117
# Epoch 306/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5324
# Epoch 307/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4127
# Epoch 308/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5236
# Epoch 309/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.6164
# Epoch 310/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3205
# Epoch 311/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3073
# Epoch 312/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5328
# Epoch 313/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3923
# Epoch 314/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4714
# Epoch 315/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3722
# Epoch 316/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3018
# Epoch 317/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2244
# Epoch 318/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0950
# Epoch 319/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1531
# Epoch 320/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0043
# Epoch 321/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1800
# Epoch 322/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0980
# Epoch 323/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1678
# Epoch 324/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0509
# Epoch 325/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1115
# Epoch 326/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0492
# Epoch 327/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8807
# Epoch 328/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7566
# Epoch 329/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9755
# Epoch 330/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0428
# Epoch 331/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9271
# Epoch 332/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8021
# Epoch 333/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7353
# Epoch 334/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8734
# Epoch 335/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0256
# Epoch 336/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7484
# Epoch 337/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7885
# Epoch 338/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8065
# Epoch 339/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5431
# Epoch 340/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8938
# Epoch 341/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8270
# Epoch 342/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6051
# Epoch 343/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7188
# Epoch 344/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6681
# Epoch 345/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8083
# Epoch 346/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6183
# Epoch 347/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6952
# Epoch 348/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5903
# Epoch 349/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5049
# Epoch 350/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5263
# Epoch 351/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5451
# Epoch 352/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5118
# Epoch 353/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5863
# Epoch 354/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4340
# Epoch 355/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5185
# Epoch 356/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5093
# Epoch 357/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8743
# Epoch 358/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4008
# Epoch 359/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4550
# Epoch 360/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4308
# Epoch 361/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5465
# Epoch 362/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4168
# Epoch 363/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5075
# Epoch 364/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4690
# Epoch 365/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3800
# Epoch 366/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2798
# Epoch 367/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7110
# Epoch 368/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4192
# Epoch 369/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5670
# Epoch 370/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3823
# Epoch 371/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6585
# Epoch 372/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5109
# Epoch 373/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4313
# Epoch 374/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5193
# Epoch 375/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3969
# Epoch 376/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4636
# Epoch 377/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5091
# Epoch 378/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4062
# Epoch 379/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6254
# Epoch 380/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4557
# Epoch 381/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3817
# Epoch 382/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5040
# Epoch 383/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3896
# Epoch 384/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4650
# Epoch 385/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4051
# Epoch 386/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4134
# Epoch 387/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3789
# Epoch 388/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3760
# Epoch 389/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4376
# Epoch 390/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3167
# Epoch 391/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3478
# Epoch 392/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3194
# Epoch 393/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3610
# Epoch 394/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3555
# Epoch 395/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3231
# Epoch 396/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3524
# Epoch 397/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4006
# Epoch 398/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4006
# Epoch 399/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3924
# Epoch 400/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3827

# %% [markdown]
# ________________________
#
#
#
# # Vanishing
#
# Lidar com Vanishing Gradient é muito mais desafiador do que com exploding gradient. Não é trivial determinar se o baixo desempenho de sua rede é causado por vanishing gradient uma vez que seus sintomas são relativamente genericos e ele pode ser apenas mais um dos fatores que prejudicam seu desempenho. Além disso não existe uma solução geral e definitiva como o gradient cliping em casos de explosão do gradiente.
#
# Preparamos algumas redes para poder explorar um caso mais simples de vanishing gradient e também uma possivel solução. Começamos gerando um dataset simples de classificação e treinamos uma rede rasa que obtem uma boa performance.
# Ao aprofundarmos essa rede podemos notar que sua performance cai drasticamente se tornando quase tão eficiente quanto jogar uma moeda para chutar a classe do ponto, ela nem mesmo é capaz de overfittar os dados. Utilizaremos o TensorBoard para explorar os gradientes dessa rede mais profunda e tentar analisar essa queda de performance. Em seguida utilizaremos uma nova forma de inicialização dos pesos da rede para tentar recuperar nossa performance e novamente inspecionar os seus gradientes para tentar ganhar algum insight do que está acontecendo dentro dela.

# %% [markdown]
# ___________
#
# ## TensorBoard e Callbacks
#
# O TensorBoard é uma ferramenta de monitoramento e visualização de redes neurais. Nós o utilizaremos para visualizar os gradientes de nossa rede e poder entender mais afundo o que está causando nosso fraco desempenho. Para mais informações sobre o TensorBoard recomendamos este [guia da documentação oficial](https://www.tensorflow.org/tensorboard/get_started). O TensorBoard pode ser iniciado como parte do notebook usando a "magica"  `%load_ext tensorboard` para carrega-lo e `%tensorboard --logdir logs/` para inicia-lo. Outra maneira de utiliza-lo é independente pelo terminal a partir dos logs salvos na pasta `log_dir` com o comando `tensorboard --logdir="logs/"`.
#
# Para utilizar o TensorBoard nós utilizamos um callback ao treinar nossa rede.
#
# [Callbacks](https://keras.io/api/callbacks/#tensorboard) são objetos do Keras capazes de realizar ações em diferentes etapas do treinamento, como a cada final de epoch ou antes de cada mini-batch. Três exemplos interessates de callbacks são o [EarlyStopping](https://keras.io/api/callbacks/early_stopping/) que te permite encerrar o treinamento de sua rede quando você atinge uma performance minima desejada, o [ModelCheckpoint](https://keras.io/api/callbacks/model_checkpoint/) que lhe permite criar checkpoints do seu modelo para poder reiniciar o treinamento sem perder todo seu progresso em caso de algum problema (como seus gradientes explodindo por exemplo) e o [LearningRateScheduler](https://keras.io/api/callbacks/learning_rate_scheduler/) que lhe permite alterar o learning rate do seu otimizador conforme a epoch de treinamento.
#
# O TensorBoard possui um callback que nos permite monitorar o desempenho e parâmetros de nosso modelo ao longo do treinamento, porém para guardar os gradientes da rede necessitamos expandir e adaptar o [callback padrão do TensorBoard](https://keras.io/api/callbacks/tensorboard/).
#
# Nós ja implementamos para vocês uma extensão desse callback no arquivo `utils.py`.
# Para usar este callback basta importa-lo e declara-lo da seguinte maneira:
#
#
# ```python
# from utils import ExtendedTensorBoard
# log_dir = "logs/"
# tensorboard_callback = ExtendedTensorBoard(x=dados_treino, y=labels_treino,log_dir=log_dir,histogram_freq=1)
# ```
# ________________

# %% [markdown]
# ## Definindo nossos dados
# Primeiro definiremos um toy dataset bem simples que utilizaremos para nossos modelos e uma função auxiliar para facilitar a comparação de nossos modelos.
#
#
# Esses dados e redes foram inspirados e adaptados [deste post](https://machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/).

# %%
# gera dataset de classificação 
X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)

# escala input para [-1,1]
scaler = MinMaxScaler(feature_range=(-1, 1))
X = scaler.fit_transform(X)

# plota visualização do dataset
for i in range(2):
    samples_ix = where(y == i)
    plt.scatter(X[samples_ix, 0], X[samples_ix, 1], label=str(i))
plt.legend()
plt.show()

# separa em teste e treino
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %%
def run_model(model,log_to_tb= False ,trainX=trainX,trainy=trainy,testX=testX,testy=testy):
    """
    Função auxiliar que recebe um modelo e realiza seu treinamento e avaliação no dataset.
    """
    model.summary()
    
    # compila modelo
    opt = keras.optimizers.SGD(lr=0.01, momentum=0.9)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    # cria log do modelo pra visualizarmos no TensorBoard se a flag estiver ligada
    callbacks = None
    if log_to_tb==True:
        log_dir = "logs/" + model.name
        callbacks=[ExtendedTensorBoard(x=trainX, y=trainy,log_dir=log_dir,histogram_freq=1)]
    

    # fit modelo
    history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=500, verbose=0, callbacks=callbacks)

    # avalia modelo
    _, train_acc = model.evaluate(trainX, trainy, verbose=0)
    _, test_acc = model.evaluate(testX, testy, verbose=0)
    print("\n")
    print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))


    # plota acurácia/training history
    plt.ylim(0, 1)
    plt.title("Acurácia "+ model.name)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='test')
    plt.xlabel("época")
    plt.ylabel("acurácia")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Rede rasa
# Aqui temos uma rede rasa com apenas uma camada oculta e uma de output, note que ela é capaz de atingir uma performance razoavel após 300 epochs.
#
# Nos estamos utilizando um inicializador diferente do padrão para os pesos da camada, ele retirar os pesos iniciais a partir de uma distribuição uniforme no intervalo [0,1].

# %%
#define modelo raso
init = RandomUniform(minval=0, maxval=1)

model = keras.Sequential(name="modelo_raso")
model.add(keras.layers.Dense(5,
                       input_dim=2,
                       activation="tanh",
                       kernel_initializer=init,
                       name="raso_1"))
model.add(keras.layers.Dense(1,
                       activation='sigmoid',
                       kernel_initializer=init,
                       name="raso_output"))


run_model(model)
# Out:
# Model: "modelo_raso"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# raso_1 (Dense)               (None, 5)                 15
# _________________________________________________________________
# raso_output (Dense)          (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Train: 0.800, Test: 0.788

# %% [markdown]
# ## Rede funda
#
# Agora tornaremos nossa rede mais funda com 5 camadas ocultas e uma de output, note como a performance cai drasticamente e se torna próxima a um chute aleatório. Embora o modelo seja mais complexo e poderoso nós não conseguimos treina-lo.

# %%
# define modelo mais fundo
init = RandomUniform(minval=0, maxval=1)

model = Sequential(name="modelo_fundo")
model.add(Dense(5, input_dim=2, activation='tanh', kernel_initializer=init,name="funda_1"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_2"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_3"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_4"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer=init,name="funda_output"))


run_model(model,log_to_tb=True)
# Out:
# Model: "modelo_fundo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# funda_1 (Dense)              (None, 5)                 15
# _________________________________________________________________
# funda_2 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_3 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_4 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_5 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_output (Dense)         (None, 1)                 6
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.251541). Check your callbacks.
#
#
# Train: 0.502, Test: 0.490

# %% [markdown]
# ### Utilizando inicialização de Xavier Glorot
#
# Agora utilizaremos uma técnica de combate ao vanishing gradient, utilizaremos outro inicializador para os pesos da rede. O [inicializador de Xavier Glorot](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf) é o inicializador default de algumas camadas do keras como a camada densa que utilizamos.

# %%
# define modelo mais fundo com inicializador de pesos melhor
model = Sequential(name="modelo_xavier")
model.add(Dense(5, input_dim=2, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_1"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_2"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_3"))
model.add(Dense(5, activation='tanh', kernel_initializer="glorot_uniform",name="xavier_4"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer="glorot_uniform", name="xavier_output"))

run_model(model,log_to_tb=True)
# Out:
# Model: "modelo_xavier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xavier_1 (Dense)             (None, 5)                 15
# _________________________________________________________________
# xavier_2 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_3 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_4 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_5 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_output (Dense)        (None, 1)                 6
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.252502). Check your callbacks.
#
#
# Train: 0.834, Test: 0.818

# %% [markdown]
# ## <font color='blue'>Questão 2 </font>
# Inicialize o TensorBoard e cheque os histogramas e as distribuições dos valores dos gradientes das 2 redes, como eles se diferem de uma rede para outra? Preste atenção em particular para a diferença de amplitude dos seus valores. Que conclusão podemos tirar? Insira/cole imagens do TensorBoard para basear seus argumentos, pode ser uma simples captura de tela.
#
# **Obs:** Você pode filtrar elementos ao escrever a tag "kernel_0_grads" como filtro para facilitar sua exploração dos gradientes dos pesos excluindo os termos de bias/viés.
#
# **Obs2:** Lembre-se de apagar a pasta `logs` se você for retreinar alguma das redes, caso contrário ele irá dar um append nos seus 2 treinamentos e seus graficos de loss e acurácia ficarão errados com loops ligando o começo de um treinamento ao final do outro.
#
# **<font color='red'> Sua resposta aqui </font>**
#
# Podemos notar que desde a primeira camada da rede funda os gradientes estão com valores muito baixos e diminuindo em cada camada, ou seja, temos um problema de vanishing gradient. A última camada se mostrou com valores um pouco melhores em relação as demais camadas alcaçando valores próximos a 0.02.
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# Utilizando a inicialização Xavier Glorot para a segunda rede, podemos notar que os gradientes se mantiveram com amplitude maior e constante durante todas as camadas da rede.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
